# %% [markdown]
# # Plotting
#
# ## Basics
# There are a few different ways to plot in Julia (including calling PyPlot). <br>
#
# Here we'll show you how to use `Plots.jl`.  If it's not installed yet, you need to use the package manager to install it, and Julia will precompile it for you the first time you use it:

# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#    Resolving package versions...
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed Libmount_jll ───────────────── v2.41.3+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed JpegTurbo_jll ──────────────── v3.1.4+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed GR_jll ─────────────────────── v0.73.24+0
#    Installed Preferences ────────────────── v1.5.2
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Opus_jll ───────────────────── v1.6.1+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed GR ─────────────────────────── v0.73.24
#    Installed MarchingCubes ──────────────── v0.1.11
#    Installed Contour ────────────────────── v0.6.3
#    Installed Measures ───────────────────── v0.3.3
#    Installed ConcurrentUtilities ────────── v2.5.1
#    Installed StaticArrays ───────────────── v1.9.17
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed PlotUtils ──────────────────── v1.4.4
#    Installed OpenSSL ────────────────────── v1.6.1
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Cairo_jll ──────────────────── v1.18.5+1
#    Installed HTTP ───────────────────────── v1.10.19
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────── v2.17.1+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed Xorg_libxkbfile_jll ────────── v1.2.0+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.7+0
#    Installed FFMPEG ─────────────────────── v0.4.5
#    Installed ColorSchemes ───────────────── v3.31.0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed UnicodePlots ───────────────── v3.8.1
#    Installed Missings ───────────────────── v1.2.0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed IrrationalConstants ────────── v0.2.6
#    Installed Pango_jll ──────────────────── v1.57.0+0
#    Installed PtrArrays ──────────────────── v1.4.0
#    Installed JSON ───────────────────────── v1.4.0
#    Installed BenchmarkTools ─────────────── v1.6.3
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed xkbcommon_jll ──────────────── v1.13.0+0
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.2+0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed StaticArraysCore ───────────── v1.4.4
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed NaNMath ────────────────────── v1.1.3
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed TranscodingStreams ─────────── v0.11.3
#    Installed GLFW_jll ───────────────────── v3.4.1+0
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed MbedTLS ────────────────────── v1.1.10
#    Installed StatsAPI ───────────────────── v1.8.0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed DataStructures ─────────────── v0.19.3
#    Installed Compat ─────────────────────── v4.18.1
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed Qt6Svg_jll ─────────────────── v6.10.2+0
#    Installed libpng_jll ─────────────────── v1.6.55+0
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed libaom_jll ─────────────────── v3.13.1+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed StatsBase ──────────────────── v0.34.10
#    Installed Scratch ────────────────────── v1.3.0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Conda ──────────────────────── v1.10.3
#    Installed Xorg_libXext_jll ───────────── v1.3.8+0
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.6+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Plots ──────────────────────── v1.41.6
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Expat_jll ──────────────────── v2.7.3+0
#    Installed Parsers ────────────────────── v2.8.3
#    Installed Libtiff_jll ────────────────── v4.7.2+0
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed PyCall ─────────────────────── v1.96.4
#    Installed Format ─────────────────────── v1.3.7
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed JLLWrappers ────────────────── v1.7.1
#    Installed OrderedCollections ─────────── v1.8.1
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.10.2+1
#    Installed Qt6Declarative_jll ─────────── v6.10.2+1
#    Installed Ghostscript_jll ────────────── v9.55.1+0
#    Installed LogExpFunctions ────────────── v0.3.29
#    Installed MbedTLS_jll ────────────────── v2.28.1010+0
#    Installed AliasTables ────────────────── v1.1.3
#    Installed MacroTools ─────────────────── v0.5.16
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Libuuid_jll ────────────────── v2.41.3+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed DocStringExtensions ────────── v0.9.5
#    Installed StableRNGs ─────────────────── v1.0.4
#    Installed Crayons ────────────────────── v4.1.1
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed Latexify ───────────────────── v0.16.10
#    Installed FFMPEG_jll ─────────────────── v8.0.1+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.6+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed Xorg_libXfixes_jll ─────────── v6.0.2+0
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Qt6Wayland_jll ─────────────── v6.10.2+1
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed PrecompileTools ────────────── v1.3.3
#    Installed Qt6Base_jll ────────────────── v6.10.2+1
#    Installed URIs ───────────────────────── v1.6.1
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed Glib_jll ───────────────────── v2.86.3+0
#    Installed VersionParsing ─────────────── v1.3.0
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Requires ───────────────────── v1.3.1
#    Installed Xorg_libX11_jll ────────────── v1.8.13+0
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed StructUtils ────────────────── v2.6.3
#    Installed SortingAlgorithms ──────────── v1.2.2
#   Installing 43 artifacts
#    Installed artifact GLFW                  266.2 KiB
#    Installed artifact Bzip2                 738.3 KiB
#    Installed artifact Vulkan_Loader         273.3 KiB
#    Installed artifact Opus                  1.2 MiB
#    Installed artifact Ogg                   276.9 KiB
#    Installed artifact LZO                   242.9 KiB
#    Installed artifact HarfBuzz              2.8 MiB
#    Installed artifact Libiconv              2.0 MiB
#    Installed artifact Cairo                 2.9 MiB
#    Installed artifact Libtiff               4.0 MiB
#    Installed artifact libvorbis             355.2 KiB
#    Installed artifact Qt6ShaderTools        2.3 MiB
#    Installed artifact Expat                 454.5 KiB
#    Installed artifact FreeType2             1.6 MiB
#    Installed artifact Graphite2             226.0 KiB
#    Installed artifact Zstd                  1.4 MiB
#    Installed artifact FriBidi               140.3 KiB
#    Installed artifact libpng                494.2 KiB
#    Installed artifact libaom                7.5 MiB
#    Installed artifact Xorg_xkeyboard_config 537.5 KiB
#    Installed artifact LLVMOpenMP            1.1 MiB
#    Installed artifact XZ                    2.4 MiB
#    Installed artifact libfdk_aac            2.9 MiB
#    Installed artifact Qt6Svg                578.5 KiB
#    Installed artifact FFMPEG                11.8 MiB
#    Installed artifact libass                509.5 KiB
#    Installed artifact Fontconfig            2.5 MiB
#    Installed artifact x265                  3.0 MiB
#    Installed artifact Pixman                444.2 KiB
#    Installed artifact GR                    20.8 MiB
#    Installed artifact Glib                  7.6 MiB
#    Installed artifact Libffi                100.5 KiB
#    Installed artifact LERC                  292.1 KiB
#    Installed artifact LAME                  408.6 KiB
#    Installed artifact x264                  2.5 MiB
#    Installed artifact JpegTurbo             1.7 MiB
#    Installed artifact MbedTLS               6.7 MiB
#    Installed artifact GettextRuntime        1.1 MiB
#    Installed artifact fzf                   3.5 MiB
#    Installed artifact Pango                 3.9 MiB
#    Installed artifact Qt6Base               25.9 MiB
#    Installed artifact Ghostscript           55.7 MiB
#    Installed artifact Qt6Declarative        32.1 MiB
#     Updating `C:\Users\yzdom\Projects\intro_to_julia_for_prog\Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.3
#   [5ae59095] + Colors v0.13.1
#   [8f4d0f93] + Conda v1.10.3
#   [7876af07] + Example v0.5.5
#   [91a5bcdd] + Plots v1.41.6
#   [438e738f] + PyCall v1.96.4
#   [b8865327] + UnicodePlots v3.8.1
#     Updating `C:\Users\yzdom\Projects\intro_to_julia_for_prog\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [6e4b80f9] + BenchmarkTools v1.6.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [34da2185] + Compat v4.18.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.1
#   [8f4d0f93] + Conda v1.10.3
#   [d38c429a] + Contour v0.6.3
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.19.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.5
#   [7876af07] + Example v0.5.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.5
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.24
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.19
#   [92d709cd] + IrrationalConstants v0.2.6
#   [1019f520] + JLFzf v0.1.11
#   [692b3bcd] + JLLWrappers v1.7.1
#   [682c06a0] + JSON v1.4.0
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.10
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.2.0
#   [1914dd2f] + MacroTools v0.5.16
#   [299715c1] + MarchingCubes v0.1.11
#   [739be429] + MbedTLS v1.1.10
#   [442fdcdd] + Measures v0.3.3
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.1.3
#   [4d8831e6] + OpenSSL v1.6.1
#   [bac558e1] + OrderedCollections v1.8.1
#   [69de0a69] + Parsers v2.8.3
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.4
#   [91a5bcdd] + Plots v1.41.6
#   [aea7be01] + PrecompileTools v1.3.3
#   [21216c6a] + Preferences v1.5.2
#   [43287f4e] + PtrArrays v1.4.0
#   [438e738f] + PyCall v1.96.4
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [189a3867] + Reexport v1.2.2
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [860ef19b] + StableRNGs v1.0.4
#   [90137ffa] + StaticArrays v1.9.17
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.8.0
#   [2913bbd2] + StatsBase v0.34.10
#   [ec057cc2] + StructUtils v2.6.3
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [b8865327] + UnicodePlots v3.8.1
#   [41fe7b60] + Unzip v0.2.0
#   [81def892] + VersionParsing v1.3.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+1
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.3+0
#   [b22a6f82] + FFMPEG_jll v8.0.1+0
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.1+0
#   [d2c73de3] + GR_jll v0.73.24+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [7746bdde] + Glib_jll v2.86.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.4+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.3+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [38a345b3] + Libuuid_jll v2.41.3+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.1010+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [91d4177d] + Opus_jll v1.6.1+0
#   [36c8627f] + Pango_jll v1.57.0+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.10.2+1
#   [629bc702] + Qt6Declarative_jll v6.10.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.10.2+1
#   [6de9746b] + Qt6Svg_jll v6.10.2+0
#   [e99dba38] + Qt6Wayland_jll v6.10.2+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.2+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.13+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.8+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.2+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.7+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.6+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.2.0+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.6+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.13.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.55+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
# ⌅ [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.13.0+0
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [2a0f44e3] + Base64 v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [f43a241f] + Downloads v1.7.0
#   [7b1f6079] + FileWatching v1.11.0
#   [b77e0a4c] + InteractiveUtils v1.11.0
#   [ac6e5ff7] + JuliaSyntaxHighlighting v1.12.0
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2 v1.11.0
#   [8f399da3] + Libdl v1.11.0
#   [37e2e46d] + LinearAlgebra v1.12.0
#   [56ddb016] + Logging v1.11.0
#   [d6f4376e] + Markdown v1.11.0
#   [a63ad114] + Mmap v1.11.0
#   [ca575930] + NetworkOptions v1.3.0
#   [44cfe95a] + Pkg v1.12.1
#   [de0858da] + Printf v1.11.0
#   [9abbd945] + Profile v1.11.0
#   [3fa0cd96] + REPL v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization v1.11.0
#   [6462fe0b] + Sockets v1.11.0
#   [2f01184e] + SparseArrays v1.12.0
#   [f489334b] + StyledStrings v1.11.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [8dfed614] + Test v1.11.0
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.3.0+1
#   [deac9b47] + LibCURL_jll v8.15.0+0
#   [e37daf67] + LibGit2_jll v1.9.0+0
#   [29816b5a] + LibSSH2_jll v1.11.3+1
#   [14a3606d] + MozillaCACerts_jll v2025.11.4
#   [4536629a] + OpenBLAS_jll v0.3.29+0
#   [05823500] + OpenLibm_jll v0.8.7+0
#   [458c3c95] + OpenSSL_jll v3.5.4+0
#   [efcefdf7] + PCRE2_jll v10.44.0+1
#   [bea87d4a] + SuiteSparse_jll v7.8.3+2
#   [83775a58] + Zlib_jll v1.3.1+2
#   [8e850b90] + libblastrampoline_jll v5.15.0+0
#   [8e850ede] + nghttp2_jll v1.64.0+1
#   [3f19e933] + p7zip_jll v17.7.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#     Building Conda ─→ `C:\Users\yzdom\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\8f06b0cfa4c514c7b9546756dbae91fcfbc92dc9\build.log`
#     Building PyCall → `C:\Users\yzdom\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9816a3826b0ebf49ab4926e2b18842ad8b5c8f04\build.log`
# Precompiling packages...
#    1130.0 ms  ✓ LaTeXStrings
#    1072.5 ms  ✓ StatsAPI
#    1065.1 ms  ✓ Contour
#    1036.0 ms  ✓ Measures
#    1076.2 ms  ✓ TensorCore
#    1154.1 ms  ✓ VersionParsing
#    1948.0 ms  ✓ Format
#     871.2 ms  ✓ StableRNGs
#    1267.0 ms  ✓ Requires
#    1054.8 ms  ✓ DocStringExtensions
#    1120.0 ms  ✓ URIs
#     801.9 ms  ✓ SimpleBufferStream
#    2853.8 ms  ✓ OrderedCollections
#    2846.4 ms  ✓ Unzip
#    3191.8 ms  ✓ Grisu
#     783.2 ms  ✓ PtrArrays
#    1051.0 ms  ✓ TranscodingStreams
#     843.5 ms  ✓ DelimitedFiles
#     739.2 ms  ✓ DataAPI
#     796.0 ms  ✓ BitFlags
#     863.6 ms  ✓ StaticArraysCore
#    3953.5 ms  ✓ IrrationalConstants
#    5339.7 ms  ✓ MacroTools
#    2581.5 ms  ✓ NaNMath
#     936.4 ms  ✓ Scratch
#    2060.8 ms  ✓ Statistics → SparseArraysExt
#    1550.3 ms  ✓ ConcurrentUtilities
#    1028.7 ms  ✓ LoggingExtras
#    1227.2 ms  ✓ Preferences
#    3685.3 ms  ✓ Crayons
#    1148.9 ms  ✓ ExceptionUnwrapping
#    3128.1 ms  ✓ StructUtils
#     973.8 ms  ✓ Showoff
#    1046.9 ms  ✓ AliasTables
#    2481.8 ms  ✓ UnicodeFun
#    2938.2 ms  ✓ Compat
#     960.0 ms  ✓ CodecZlib
#    2738.8 ms  ✓ DataStructures
#    1209.2 ms  ✓ LogExpFunctions
#     924.1 ms  ✓ RelocatableFolders
#    1033.4 ms  ✓ JLLWrappers
#     928.0 ms  ✓ PrecompileTools
#     929.1 ms  ✓ Compat → CompatLinearAlgebraExt
#    2787.5 ms  ✓ Missings
#    1108.0 ms  ✓ SortingAlgorithms
#    1322.4 ms  ✓ Graphite2_jll
#    1177.5 ms  ✓ Libmount_jll
#    1144.0 ms  ✓ EpollShim_jll
#    5288.0 ms  ✓ ColorVectorSpace
#    1334.0 ms  ✓ LLVMOpenMP_jll
#    3696.1 ms  ✓ OpenSSL
#    1334.8 ms  ✓ Bzip2_jll
#    1181.1 ms  ✓ Xorg_libICE_jll
#    1137.1 ms  ✓ Xorg_libXau_jll
#    1220.0 ms  ✓ libfdk_aac_jll
#    1290.0 ms  ✓ libpng_jll
#    1253.5 ms  ✓ LAME_jll
#    1240.7 ms  ✓ LERC_jll
#    1233.9 ms  ✓ fzf_jll
#    1375.6 ms  ✓ JpegTurbo_jll
#    1066.5 ms  ✓ mtdev_jll
#    1546.6 ms  ✓ XZ_jll
#    1324.5 ms  ✓ Ogg_jll
#    1439.0 ms  ✓ Xorg_libXdmcp_jll
#    2078.5 ms  ✓ x265_jll
#    2004.6 ms  ✓ x264_jll
#    1873.7 ms  ✓ Zstd_jll
#    2263.5 ms  ✓ MbedTLS_jll
#    2077.9 ms  ✓ libaom_jll
#    1863.2 ms  ✓ Expat_jll
#    2116.0 ms  ✓ LZO_jll
#    1854.9 ms  ✓ Xorg_xtrans_jll
#    1867.9 ms  ✓ Opus_jll
#    1803.6 ms  ✓ eudev_jll
#    1815.6 ms  ✓ Libffi_jll
#    1828.3 ms  ✓ Libiconv_jll
#    1837.0 ms  ✓ libevdev_jll
#    1665.6 ms  ✓ Libuuid_jll
#    1856.1 ms  ✓ FriBidi_jll
#    1995.1 ms  ✓ FreeType2_jll
#    2581.2 ms  ✓ Pixman_jll
#    3656.1 ms  ✓ RecipesBase
#    1876.1 ms  ✓ Xorg_libSM_jll
#    1862.1 ms  ✓ JLFzf
#    2085.3 ms  ✓ libvorbis_jll
#    2076.7 ms  ✓ Xorg_libxcb_jll
#    3499.3 ms  ✓ Ghostscript_jll
#    7128.9 ms  ✓ StatsBase
#    8048.5 ms  ✓ ColorSchemes
#    2474.3 ms  ✓ Wayland_jll
#    2462.8 ms  ✓ Dbus_jll
#    3044.3 ms  ✓ Libtiff_jll
#    2572.4 ms  ✓ GettextRuntime_jll
#    1687.8 ms  ✓ libinput_jll
#    4402.9 ms  ✓ MbedTLS
#    1687.3 ms  ✓ Xorg_xcb_util_jll
#    1570.2 ms  ✓ Xorg_libX11_jll
#    2641.5 ms  ✓ Fontconfig_jll
#    1134.7 ms  ✓ Xorg_xcb_util_image_jll
#    1923.1 ms  ✓ Glib_jll
#     960.7 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1049.4 ms  ✓ Xorg_xcb_util_renderutil_jll
#     987.2 ms  ✓ Xorg_xcb_util_wm_jll
#     939.6 ms  ✓ Xorg_libXrender_jll
#    1410.8 ms  ✓ Xorg_libXext_jll
#    1491.8 ms  ✓ Xorg_libXfixes_jll
#   18110.7 ms  ✓ StaticArrays
#    1452.0 ms  ✓ Xorg_libxkbfile_jll
#    1270.1 ms  ✓ Xorg_xcb_util_cursor_jll
#    1777.0 ms  ✓ Xorg_libXinerama_jll
#    1336.0 ms  ✓ Xorg_libXrandr_jll
#    1241.6 ms  ✓ Libglvnd_jll
#    8777.7 ms  ✓ Latexify
#    1859.1 ms  ✓ Xorg_libXcursor_jll
#    1813.8 ms  ✓ Xorg_libXi_jll
#    2092.6 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    3097.7 ms  ✓ Cairo_jll
#    1801.8 ms  ✓ Xorg_xkbcomp_jll
#   24152.9 ms  ✓ Parsers
#    2275.5 ms  ✓ Latexify → SparseArraysExt
#    2349.4 ms  ✓ HarfBuzz_jll
#    1442.5 ms  ✓ Xorg_xkeyboard_config_jll
#    1772.9 ms  ✓ xkbcommon_jll
#    2819.9 ms  ✓ libass_jll
#    2803.9 ms  ✓ Pango_jll
#    1472.2 ms  ✓ Vulkan_Loader_jll
#    3497.4 ms  ✓ libdecor_jll
#    9921.2 ms  ✓ MarchingCubes
#   20702.5 ms  ✓ PlotUtils
#    4901.2 ms  ✓ Qt6Base_jll
#    2219.7 ms  ✓ GLFW_jll
#   10178.6 ms  ✓ JSON
#    7494.7 ms  ✓ FFMPEG_jll
#    2135.4 ms  ✓ Conda
#    4289.6 ms  ✓ Qt6ShaderTools_jll
#    5911.1 ms  ✓ Qt6Svg_jll
#    6897.6 ms  ✓ PlotThemes
#    4204.8 ms  ✓ BenchmarkTools
#    8797.1 ms  ✓ RecipesPipeline
#    3757.7 ms  ✓ FFMPEG
#    4204.5 ms  ✓ GR_jll
#    5579.5 ms  ✓ Qt6Declarative_jll
#   35225.8 ms  ✓ HTTP
#     757.5 ms  ✓ Qt6Wayland_jll
#    5630.4 ms  ✓ GR
#   22486.0 ms  ✓ PyCall
#   58975.4 ms  ✓ UnicodePlots
#   50053.5 ms  ✓ Plots
#   148 dependencies successfully precompiled in 124 seconds. 44 already precompiled.

# %% [markdown]
# One of the advantages to `Plots.jl` is that it allows you to seamlessly change backends. In this notebook, we'll try out the `gr()` and `plotlyjs()` backends.<br>
#
# In the name of scientific inquiry, let's use this notebook to examine the relationship between the global temperature and the number of pirates between roughly 1860 and 2000.

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17];

# %% [markdown]
# Plots supports multiple backends — that is, libraries that actually do the drawing — all with the same API. To start out, let's try the GR backend.  You choose it with a call to `gr()`:

# %%
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# and now we can use commands like `plot` and `scatter` to generate plots.

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points")

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter(numpirates, globaltemperatures, label="points")

# %% [markdown]
# The `!` at the end of the `scatter!` function name makes `scatter!` a mutating function, indicating that the scattered points will be added onto the pre-existing plot.
#
# In contrast, see what happens when you replace `scatter!` in the above with the non-mutating function `scatter`.
#
# Next, let's update this plot with the `xlabel!`, `ylabel!`, and `title!` commands to add more information to our plot.

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points") 

xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %% [markdown]
# This still doesn't look quite right. The number of pirates has decreased since 1860, so reading the plot from left to right is like looking backwards in time rather than forwards. Let's flip the x axis to better see how pirate populations have caused global temperatures to change over time!

# %%
xflip!()

# %% [markdown]
# And there we have it!
#
# Note: We've had some confusion about this exercise. :) This is a joke about how people often conflate correlation and causation.
#
# **Without changing syntax, we can create this plot with the UnicodePlots backend**

# %%
Pkg.add("UnicodePlots")
unicodeplots()
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\yzdom\Projects\intro_to_julia_for_prog\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\yzdom\Projects\intro_to_julia_for_prog\Manifest.toml`
# Plots.UnicodePlotsBackend()

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points") 
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")
# Out:
#                       Influence of pirate population on global warming
#                       ┌────────────────────────────────────────┐
#                 15.842│⠀⚬⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│line
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│points
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠈⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
# Global Temperature (C)│⠀⡇⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                       │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⚬⠤⠤⠤⢄⣀⣀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                 14.358│⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠒⠒⠒⠒⠒⠤⚬⠀│
#                       └────────────────────────────────────────┘
#                       ⠀-1332.49Number of Pirates [Approximate]46349.5⠀

# %% [markdown]
# And notice how this second plot differs from the first!  Using text like this is a little silly in a Jupyter notebook where we have fancy drawing capabilities, but it can be very useful for quick and dirty visualization in a terminal.

# %% [markdown]
# ### Exercises
#
# #### 8.1
# Given
# ```julia
# x = -10:10
# ```
# plot y vs. x for $y = x^2$.  You may want to change backends back again.

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
x = -10:10
y = x .^ 2
plot(x, y, label="line")
scatter!(x, y, label="points")
xlabel!("x")
ylabel!("y")
title!("Plot of y = x^2")

# %% [markdown]
# #### 8.2
# Execute the following code

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %% [markdown]
# and then create a $4x1$ plot that uses `p1`, `p2`, `p3`, and `p4` as subplots.

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (1, 4), legend = false, size=(800, 200))
